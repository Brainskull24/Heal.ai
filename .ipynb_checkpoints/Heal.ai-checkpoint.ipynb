# %% [markdown]
# # MENTAL HEALTH PREDICTION MODEL USING MACHINE LEARNING
#
# ## We will have multiple stages for creating this project and the steps will be as follows:
#
# ### 1. Preprocessing of Data
# ### 2. Model Training
# ### 3. Creating Frontend to implement the model
# ### 4. Result Analysis
#
#
# ### The Dataset we are going to use is MOCK_DATA.csv which we have build ourselves...

# %%
# firstly import libraries like pandas and numpy for data preprocessing using import command
import pandas as pd
import numpy as np

# %%
# read the csv file using read_csv function
df = pd.read_csv("MOCK_DATA.csv")

# %% [markdown]
# # As you can see below is our dataset consisting of 1000 rows and 20 columns

# %%
df
# Out:
#                  NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0     Junette Griffin   22  Female    Student               Marketing
# 1        Donn Ricoald   32    Male    Student  Electrical Engineering
# 2        Brandon Gush   33    Male    Teacher                 Finance
# 3     Roger Littlekit   19    Male    Student               Marketing
# 4    Clarke Sterricks   27    Male    Teacher              Psychology
# ..                ...  ...     ...        ...                     ...
# 995  Eberhard Widmoor   20    Male    Teacher                 Finance
# 996   Beverley Mainds   20  Female    Teacher              Psychology
# 997      Jere Shaplin   30  Female    Teacher          Graphic Design
# 998      Hughie Rowet   36    Male    Student  Mechanical Engineering
# 999      Elle Rabbitt   33  Female    Student               Marketing
#
#     MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0               Yes          2-3 hours         Every hour        Twitter
# 1                No          1-2 hours   Every 15 minutes       Facebook
# 2               Yes  More than 5 hours  Every few minutes        Twitter
# 3               Yes          2-3 hours  Every few minutes      Instagram
# 4               Yes          1-2 hours  Every few minutes       Facebook
# ..              ...                ...                ...            ...
# 995              No          3-4 hours   Every 15 minutes        Twitter
# 996              No          2-3 hours   Every 15 minutes        Twitter
# 997              No          1-2 hours   Every 15 minutes      Instagram
# 998             Yes          3-4 hours   Every 15 minutes       Facebook
# 999              No          1-2 hours   Every 15 minutes      Instagram
#
#     Anxiety/Stress Away From Phone Feeling Without Phone SOCIAL ENGAGEMENT  \
# 0                              yes                 Bored               Yes
# 1                              yes            Productive      occasionally
# 2                               No                 Bored        frequently
# 3                              yes            Frustrated        frequently
# 4                               No                Joyful               Yes
# ..                             ...                   ...               ...
# 995                            yes            Frustrated               Yes
# 996                            yes                Joyful               Yes
# 997                             No              Relieved        frequently
# 998                             No                Joyful        frequently
# 999                            yes              Relieved        frequently
#
#     Phone Reduction Attempt      Reduction Success  \
# 0                       Yes        Very successful
# 1                        No    Somewhat successful
# 2                        No        Very successful
# 3                        No  Not at all successful
# 4                       Yes        Very successful
# ..                      ...                    ...
# 995                     Yes    Somewhat successful
# 996                      No  Not at all successful
# 997                     Yes    Somewhat successful
# 998                     Yes    Somewhat successful
# 999                     Yes    Somewhat successful
#
#                    Focus Ability Phone Impact on Lifestyle WELL BEING  \
# 0                        Neutral                      Fair        Bad
# 1                        Neutral                      Good        Bad
# 2    Somewhat difficult to focus                   Neutral       Good
# 3    Somewhat difficult to focus                      Good       Good
# 4             Very easy to focus                      Good       Good
# ..                           ...                       ...        ...
# 995  Somewhat difficult to focus                   Neutral       Good
# 996                      Neutral                   Neutral    Neutral
# 997  Somewhat difficult to focus                      Good       Good
# 998  Somewhat difficult to focus                   Neutral        Bad
# 999           Very easy to focus                      Fair       Good
#
#     Plan to Reduce Phone Usage                         Steps to Reduce Usage  \
# 0                          Yes                  Practice mindful phone usage
# 1                          Yes                        Set phone usage limits
# 2                           No                    Disable push notifications
# 3                          Yes                      Create a phone-free zone
# 4                           No                   Practice digital detox days
# ..                         ...                                           ...
# 995                         No                      Create a phone-free zone
# 996                        Yes                      Create a phone-free zone
# 997                         No                      Use a phone tracking app
# 998                         No  Set specific times for checking social media
# 999                         No                    Disable push notifications
#
#      sleep duration
# 0                 9
# 1                 7
# 2                14
# 3                 4
# 4                14
# ..              ...
# 995               9
# 996              11
# 997              13
# 998              14
# 999               8
#
# [1000 rows x 20 columns]

# %% [markdown]
# # Now we have seen our dataset carefully let's start with our first task i.e. data    preprocessing

# %%
value_counts_A = df['FIELD OF STUDY'].value_counts()
value_counts_B = df['SOCIAL ENGAGEMENT'].value_counts()
value_counts_C = df['Steps to Reduce Usage'].value_counts()

print(value_counts_B)
# Out:
# SOCIAL ENGAGEMENT
# Yes             500
# occasionally    253
# frequently      247
# Name: count, dtype: int64

# %%
for index, value in df['SOCIAL ENGAGEMENT'].items():
    if value == 'Yes':
        df.at[index, 'SOCIAL ENGAGEMENT'] = 'rarely'

df
# Out:
#                  NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0     Junette Griffin   22  Female    Student               Marketing
# 1        Donn Ricoald   32    Male    Student  Electrical Engineering
# 2        Brandon Gush   33    Male    Teacher                 Finance
# 3     Roger Littlekit   19    Male    Student               Marketing
# 4    Clarke Sterricks   27    Male    Teacher              Psychology
# ..                ...  ...     ...        ...                     ...
# 995  Eberhard Widmoor   20    Male    Teacher                 Finance
# 996   Beverley Mainds   20  Female    Teacher              Psychology
# 997      Jere Shaplin   30  Female    Teacher          Graphic Design
# 998      Hughie Rowet   36    Male    Student  Mechanical Engineering
# 999      Elle Rabbitt   33  Female    Student               Marketing
#
#     MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0               Yes          2-3 hours         Every hour        Twitter
# 1                No          1-2 hours   Every 15 minutes       Facebook
# 2               Yes  More than 5 hours  Every few minutes        Twitter
# 3               Yes          2-3 hours  Every few minutes      Instagram
# 4               Yes          1-2 hours  Every few minutes       Facebook
# ..              ...                ...                ...            ...
# 995              No          3-4 hours   Every 15 minutes        Twitter
# 996              No          2-3 hours   Every 15 minutes        Twitter
# 997              No          1-2 hours   Every 15 minutes      Instagram
# 998             Yes          3-4 hours   Every 15 minutes       Facebook
# 999              No          1-2 hours   Every 15 minutes      Instagram
#
#     Anxiety/Stress Away From Phone Feeling Without Phone SOCIAL ENGAGEMENT  \
# 0                              yes                 Bored            rarely
# 1                              yes            Productive      occasionally
# 2                               No                 Bored        frequently
# 3                              yes            Frustrated        frequently
# 4                               No                Joyful            rarely
# ..                             ...                   ...               ...
# 995                            yes            Frustrated            rarely
# 996                            yes                Joyful            rarely
# 997                             No              Relieved        frequently
# 998                             No                Joyful        frequently
# 999                            yes              Relieved        frequently
#
#     Phone Reduction Attempt      Reduction Success  \
# 0                       Yes        Very successful
# 1                        No    Somewhat successful
# 2                        No        Very successful
# 3                        No  Not at all successful
# 4                       Yes        Very successful
# ..                      ...                    ...
# 995                     Yes    Somewhat successful
# 996                      No  Not at all successful
# 997                     Yes    Somewhat successful
# 998                     Yes    Somewhat successful
# 999                     Yes    Somewhat successful
#
#                    Focus Ability Phone Impact on Lifestyle WELL BEING  \
# 0                        Neutral                      Fair        Bad
# 1                        Neutral                      Good        Bad
# 2    Somewhat difficult to focus                   Neutral       Good
# 3    Somewhat difficult to focus                      Good       Good
# 4             Very easy to focus                      Good       Good
# ..                           ...                       ...        ...
# 995  Somewhat difficult to focus                   Neutral       Good
# 996                      Neutral                   Neutral    Neutral
# 997  Somewhat difficult to focus                      Good       Good
# 998  Somewhat difficult to focus                   Neutral        Bad
# 999           Very easy to focus                      Fair       Good
#
#     Plan to Reduce Phone Usage                         Steps to Reduce Usage  \
# 0                          Yes                  Practice mindful phone usage
# 1                          Yes                        Set phone usage limits
# 2                           No                    Disable push notifications
# 3                          Yes                      Create a phone-free zone
# 4                           No                   Practice digital detox days
# ..                         ...                                           ...
# 995                         No                      Create a phone-free zone
# 996                        Yes                      Create a phone-free zone
# 997                         No                      Use a phone tracking app
# 998                         No  Set specific times for checking social media
# 999                         No                    Disable push notifications
#
#      sleep duration
# 0                 9
# 1                 7
# 2                14
# 3                 4
# 4                14
# ..              ...
# 995               9
# 996              11
# 997              13
# 998              14
# 999               8
#
# [1000 rows x 20 columns]

# %%
increase_count = 70

# Identify indices where 'rarely' is present
rarely_indices = df[df['SOCIAL ENGAGEMENT'] == 'rarely'].index

# Randomly select indices from 'rarely' and update them to 'frequently' and 'occasionally'
selected_indices = np.random.choice(rarely_indices, size=increase_count * 2, replace=False)

# Update the 'new_social_engagement' column
df.loc[selected_indices[:increase_count], 'SOCIAL ENGAGEMENT'] = 'frequently'
df.loc[selected_indices[increase_count:], 'SOCIAL ENGAGEMENT'] = 'occasionally'

# Update the counts in the new column
new_counts = df['SOCIAL ENGAGEMENT'].value_counts()

# %%
value_counts_A = df['FIELD OF STUDY'].value_counts()
value_counts_B = df['SOCIAL ENGAGEMENT'].value_counts()
value_counts_C = df['Steps to Reduce Usage'].value_counts()

print(value_counts_B)
# Out:
# SOCIAL ENGAGEMENT
# rarely          360
# occasionally    323
# frequently      317
# Name: count, dtype: int64

# %%
for index, row in df.iterrows():
    if row['OCCUPATION'] == 'Teacher' and row['AGE'] <= 20:
        df.at[index, 'OCCUPATION'] = 'Student'

for index, row in df.iterrows():
    if row['OCCUPATION'] == 'Student' and row['AGE'] >= 30:
        df.at[index, 'OCCUPATION'] = 'Teacher'

# %%
print(value_counts_A)
# Out:
# FIELD OF STUDY
# Marketing                  108
# Biology                    104
# Computer Science           104
# Psychology                 102
# Business Administration    102
# Civil Engineering          102
# Electrical Engineering     101
# Finance                     96
# Graphic Design              92
# Mechanical Engineering      89
# Name: count, dtype: int64

# %%
# defining a new column of how much usage they normally should have
df['expected_usage'] = ''

for index, row in df.iterrows():
    field_of_study = row['FIELD OF STUDY']
    
    if field_of_study in ['Marketing', 'Finance','Computer Science',]:
        df.at[index, 'expected_usage'] = 'High'
    elif field_of_study in [ 'Electrical Engineering', 'Business Administration','Mechanical Engineering']:
        df.at[index, 'expected_usage'] = 'Medium'
    else:
        df.at[index, 'expected_usage'] = 'Low'

df
# Out:
#                  NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0     Junette Griffin   22  Female    Student               Marketing
# 1        Donn Ricoald   32    Male    Teacher  Electrical Engineering
# 2        Brandon Gush   33    Male    Teacher                 Finance
# 3     Roger Littlekit   19    Male    Student               Marketing
# 4    Clarke Sterricks   27    Male    Teacher              Psychology
# ..                ...  ...     ...        ...                     ...
# 995  Eberhard Widmoor   20    Male    Student                 Finance
# 996   Beverley Mainds   20  Female    Student              Psychology
# 997      Jere Shaplin   30  Female    Teacher          Graphic Design
# 998      Hughie Rowet   36    Male    Teacher  Mechanical Engineering
# 999      Elle Rabbitt   33  Female    Teacher               Marketing
#
#     MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0               Yes          2-3 hours         Every hour        Twitter
# 1                No          1-2 hours   Every 15 minutes       Facebook
# 2               Yes  More than 5 hours  Every few minutes        Twitter
# 3               Yes          2-3 hours  Every few minutes      Instagram
# 4               Yes          1-2 hours  Every few minutes       Facebook
# ..              ...                ...                ...            ...
# 995              No          3-4 hours   Every 15 minutes        Twitter
# 996              No          2-3 hours   Every 15 minutes        Twitter
# 997              No          1-2 hours   Every 15 minutes      Instagram
# 998             Yes          3-4 hours   Every 15 minutes       Facebook
# 999              No          1-2 hours   Every 15 minutes      Instagram
#
#     Anxiety/Stress Away From Phone  ... SOCIAL ENGAGEMENT  \
# 0                              yes  ...            rarely
# 1                              yes  ...      occasionally
# 2                               No  ...        frequently
# 3                              yes  ...        frequently
# 4                               No  ...            rarely
# ..                             ...  ...               ...
# 995                            yes  ...        frequently
# 996                            yes  ...            rarely
# 997                             No  ...        frequently
# 998                             No  ...        frequently
# 999                            yes  ...        frequently
#
#     Phone Reduction Attempt      Reduction Success  \
# 0                       Yes        Very successful
# 1                        No    Somewhat successful
# 2                        No        Very successful
# 3                        No  Not at all successful
# 4                       Yes        Very successful
# ..                      ...                    ...
# 995                     Yes    Somewhat successful
# 996                      No  Not at all successful
# 997                     Yes    Somewhat successful
# 998                     Yes    Somewhat successful
# 999                     Yes    Somewhat successful
#
#                    Focus Ability Phone Impact on Lifestyle WELL BEING  \
# 0                        Neutral                      Fair        Bad
# 1                        Neutral                      Good        Bad
# 2    Somewhat difficult to focus                   Neutral       Good
# 3    Somewhat difficult to focus                      Good       Good
# 4             Very easy to focus                      Good       Good
# ..                           ...                       ...        ...
# 995  Somewhat difficult to focus                   Neutral       Good
# 996                      Neutral                   Neutral    Neutral
# 997  Somewhat difficult to focus                      Good       Good
# 998  Somewhat difficult to focus                   Neutral        Bad
# 999           Very easy to focus                      Fair       Good
#
#     Plan to Reduce Phone Usage                         Steps to Reduce Usage  \
# 0                          Yes                  Practice mindful phone usage
# 1                          Yes                        Set phone usage limits
# 2                           No                    Disable push notifications
# 3                          Yes                      Create a phone-free zone
# 4                           No                   Practice digital detox days
# ..                         ...                                           ...
# 995                         No                      Create a phone-free zone
# 996                        Yes                      Create a phone-free zone
# 997                         No                      Use a phone tracking app
# 998                         No  Set specific times for checking social media
# 999                         No                    Disable push notifications
#
#     sleep duration  expected_usage
# 0                9            High
# 1                7          Medium
# 2               14            High
# 3                4            High
# 4               14             Low
# ..             ...             ...
# 995              9            High
# 996             11             Low
# 997             13             Low
# 998             14          Medium
# 999              8            High
#
# [1000 rows x 21 columns]

# %%
value_counts_F = df['sleep duration'].value_counts()
print(value_counts_F)
# Out:
# sleep duration
# 13    82
# 15    80
# 4     79
# 10    76
# 9     74
# 12    73
# 5     68
# 8     67
# 7     66
# 3     63
# 2     58
# 14    56
# 1     55
# 11    54
# 6     49
# Name: count, dtype: int64

# %%
bins = [1, 5, 10, float('inf')]
labels = ['Below 5 hours', '5-9 hours', 'Above 9 hours']

# Create a new column 'Time Slot' based on sleep duration categories
df['Time Slot'] = pd.cut(df['sleep duration'], bins=bins, labels=labels, right=False)

# Display the updated DataFrame
df
# Out:
#                  NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0     Junette Griffin   22  Female    Student               Marketing
# 1        Donn Ricoald   32    Male    Teacher  Electrical Engineering
# 2        Brandon Gush   33    Male    Teacher                 Finance
# 3     Roger Littlekit   19    Male    Student               Marketing
# 4    Clarke Sterricks   27    Male    Teacher              Psychology
# ..                ...  ...     ...        ...                     ...
# 995  Eberhard Widmoor   20    Male    Student                 Finance
# 996   Beverley Mainds   20  Female    Student              Psychology
# 997      Jere Shaplin   30  Female    Teacher          Graphic Design
# 998      Hughie Rowet   36    Male    Teacher  Mechanical Engineering
# 999      Elle Rabbitt   33  Female    Teacher               Marketing
#
#     MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0               Yes          2-3 hours         Every hour        Twitter
# 1                No          1-2 hours   Every 15 minutes       Facebook
# 2               Yes  More than 5 hours  Every few minutes        Twitter
# 3               Yes          2-3 hours  Every few minutes      Instagram
# 4               Yes          1-2 hours  Every few minutes       Facebook
# ..              ...                ...                ...            ...
# 995              No          3-4 hours   Every 15 minutes        Twitter
# 996              No          2-3 hours   Every 15 minutes        Twitter
# 997              No          1-2 hours   Every 15 minutes      Instagram
# 998             Yes          3-4 hours   Every 15 minutes       Facebook
# 999              No          1-2 hours   Every 15 minutes      Instagram
#
#     Anxiety/Stress Away From Phone  ... Phone Reduction Attempt  \
# 0                              yes  ...                     Yes
# 1                              yes  ...                      No
# 2                               No  ...                      No
# 3                              yes  ...                      No
# 4                               No  ...                     Yes
# ..                             ...  ...                     ...
# 995                            yes  ...                     Yes
# 996                            yes  ...                      No
# 997                             No  ...                     Yes
# 998                             No  ...                     Yes
# 999                            yes  ...                     Yes
#
#          Reduction Success                Focus Ability  \
# 0          Very successful                      Neutral
# 1      Somewhat successful                      Neutral
# 2          Very successful  Somewhat difficult to focus
# 3    Not at all successful  Somewhat difficult to focus
# 4          Very successful           Very easy to focus
# ..                     ...                          ...
# 995    Somewhat successful  Somewhat difficult to focus
# 996  Not at all successful                      Neutral
# 997    Somewhat successful  Somewhat difficult to focus
# 998    Somewhat successful  Somewhat difficult to focus
# 999    Somewhat successful           Very easy to focus
#
#     Phone Impact on Lifestyle WELL BEING Plan to Reduce Phone Usage  \
# 0                        Fair        Bad                        Yes
# 1                        Good        Bad                        Yes
# 2                     Neutral       Good                         No
# 3                        Good       Good                        Yes
# 4                        Good       Good                         No
# ..                        ...        ...                        ...
# 995                   Neutral       Good                         No
# 996                   Neutral    Neutral                        Yes
# 997                      Good       Good                         No
# 998                   Neutral        Bad                         No
# 999                      Fair       Good                         No
#
#                             Steps to Reduce Usage sleep duration  \
# 0                    Practice mindful phone usage              9
# 1                          Set phone usage limits              7
# 2                      Disable push notifications             14
# 3                        Create a phone-free zone              4
# 4                     Practice digital detox days             14
# ..                                            ...            ...
# 995                      Create a phone-free zone              9
# 996                      Create a phone-free zone             11
# 997                      Use a phone tracking app             13
# 998  Set specific times for checking social media             14
# 999                    Disable push notifications              8
#
#     expected_usage      Time Slot
# 0             High      5-9 hours
# 1           Medium      5-9 hours
# 2             High  Above 9 hours
# 3             High  Below 5 hours
# 4              Low  Above 9 hours
# ..             ...            ...
# 995           High      5-9 hours
# 996            Low  Above 9 hours
# 997            Low  Above 9 hours
# 998         Medium  Above 9 hours
# 999           High      5-9 hours
#
# [1000 rows x 22 columns]

# %%
df = df.drop(columns = ['sleep duration'])

# %%
df
# Out:
#                  NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0     Junette Griffin   22  Female    Student               Marketing
# 1        Donn Ricoald   32    Male    Teacher  Electrical Engineering
# 2        Brandon Gush   33    Male    Teacher                 Finance
# 3     Roger Littlekit   19    Male    Student               Marketing
# 4    Clarke Sterricks   27    Male    Teacher              Psychology
# ..                ...  ...     ...        ...                     ...
# 995  Eberhard Widmoor   20    Male    Student                 Finance
# 996   Beverley Mainds   20  Female    Student              Psychology
# 997      Jere Shaplin   30  Female    Teacher          Graphic Design
# 998      Hughie Rowet   36    Male    Teacher  Mechanical Engineering
# 999      Elle Rabbitt   33  Female    Teacher               Marketing
#
#     MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0               Yes          2-3 hours         Every hour        Twitter
# 1                No          1-2 hours   Every 15 minutes       Facebook
# 2               Yes  More than 5 hours  Every few minutes        Twitter
# 3               Yes          2-3 hours  Every few minutes      Instagram
# 4               Yes          1-2 hours  Every few minutes       Facebook
# ..              ...                ...                ...            ...
# 995              No          3-4 hours   Every 15 minutes        Twitter
# 996              No          2-3 hours   Every 15 minutes        Twitter
# 997              No          1-2 hours   Every 15 minutes      Instagram
# 998             Yes          3-4 hours   Every 15 minutes       Facebook
# 999              No          1-2 hours   Every 15 minutes      Instagram
#
#     Anxiety/Stress Away From Phone  ... SOCIAL ENGAGEMENT  \
# 0                              yes  ...            rarely
# 1                              yes  ...      occasionally
# 2                               No  ...        frequently
# 3                              yes  ...        frequently
# 4                               No  ...            rarely
# ..                             ...  ...               ...
# 995                            yes  ...        frequently
# 996                            yes  ...            rarely
# 997                             No  ...        frequently
# 998                             No  ...        frequently
# 999                            yes  ...        frequently
#
#     Phone Reduction Attempt      Reduction Success  \
# 0                       Yes        Very successful
# 1                        No    Somewhat successful
# 2                        No        Very successful
# 3                        No  Not at all successful
# 4                       Yes        Very successful
# ..                      ...                    ...
# 995                     Yes    Somewhat successful
# 996                      No  Not at all successful
# 997                     Yes    Somewhat successful
# 998                     Yes    Somewhat successful
# 999                     Yes    Somewhat successful
#
#                    Focus Ability Phone Impact on Lifestyle WELL BEING  \
# 0                        Neutral                      Fair        Bad
# 1                        Neutral                      Good        Bad
# 2    Somewhat difficult to focus                   Neutral       Good
# 3    Somewhat difficult to focus                      Good       Good
# 4             Very easy to focus                      Good       Good
# ..                           ...                       ...        ...
# 995  Somewhat difficult to focus                   Neutral       Good
# 996                      Neutral                   Neutral    Neutral
# 997  Somewhat difficult to focus                      Good       Good
# 998  Somewhat difficult to focus                   Neutral        Bad
# 999           Very easy to focus                      Fair       Good
#
#     Plan to Reduce Phone Usage                         Steps to Reduce Usage  \
# 0                          Yes                  Practice mindful phone usage
# 1                          Yes                        Set phone usage limits
# 2                           No                    Disable push notifications
# 3                          Yes                      Create a phone-free zone
# 4                           No                   Practice digital detox days
# ..                         ...                                           ...
# 995                         No                      Create a phone-free zone
# 996                        Yes                      Create a phone-free zone
# 997                         No                      Use a phone tracking app
# 998                         No  Set specific times for checking social media
# 999                         No                    Disable push notifications
#
#     expected_usage      Time Slot
# 0             High      5-9 hours
# 1           Medium      5-9 hours
# 2             High  Above 9 hours
# 3             High  Below 5 hours
# 4              Low  Above 9 hours
# ..             ...            ...
# 995           High      5-9 hours
# 996            Low  Above 9 hours
# 997            Low  Above 9 hours
# 998         Medium  Above 9 hours
# 999           High      5-9 hours
#
# [1000 rows x 21 columns]

# %%
# renaming the column name
df.rename(columns={'Time Slot': 'sleep time'}, inplace=True)

# %%
df
# Out:
#                  NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0     Junette Griffin   22  Female    Student               Marketing
# 1        Donn Ricoald   32    Male    Teacher  Electrical Engineering
# 2        Brandon Gush   33    Male    Teacher                 Finance
# 3     Roger Littlekit   19    Male    Student               Marketing
# 4    Clarke Sterricks   27    Male    Teacher              Psychology
# ..                ...  ...     ...        ...                     ...
# 995  Eberhard Widmoor   20    Male    Student                 Finance
# 996   Beverley Mainds   20  Female    Student              Psychology
# 997      Jere Shaplin   30  Female    Teacher          Graphic Design
# 998      Hughie Rowet   36    Male    Teacher  Mechanical Engineering
# 999      Elle Rabbitt   33  Female    Teacher               Marketing
#
#     MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0               Yes          2-3 hours         Every hour        Twitter
# 1                No          1-2 hours   Every 15 minutes       Facebook
# 2               Yes  More than 5 hours  Every few minutes        Twitter
# 3               Yes          2-3 hours  Every few minutes      Instagram
# 4               Yes          1-2 hours  Every few minutes       Facebook
# ..              ...                ...                ...            ...
# 995              No          3-4 hours   Every 15 minutes        Twitter
# 996              No          2-3 hours   Every 15 minutes        Twitter
# 997              No          1-2 hours   Every 15 minutes      Instagram
# 998             Yes          3-4 hours   Every 15 minutes       Facebook
# 999              No          1-2 hours   Every 15 minutes      Instagram
#
#     Anxiety/Stress Away From Phone  ... SOCIAL ENGAGEMENT  \
# 0                              yes  ...            rarely
# 1                              yes  ...      occasionally
# 2                               No  ...        frequently
# 3                              yes  ...        frequently
# 4                               No  ...            rarely
# ..                             ...  ...               ...
# 995                            yes  ...        frequently
# 996                            yes  ...            rarely
# 997                             No  ...        frequently
# 998                             No  ...        frequently
# 999                            yes  ...        frequently
#
#     Phone Reduction Attempt      Reduction Success  \
# 0                       Yes        Very successful
# 1                        No    Somewhat successful
# 2                        No        Very successful
# 3                        No  Not at all successful
# 4                       Yes        Very successful
# ..                      ...                    ...
# 995                     Yes    Somewhat successful
# 996                      No  Not at all successful
# 997                     Yes    Somewhat successful
# 998                     Yes    Somewhat successful
# 999                     Yes    Somewhat successful
#
#                    Focus Ability Phone Impact on Lifestyle WELL BEING  \
# 0                        Neutral                      Fair        Bad
# 1                        Neutral                      Good        Bad
# 2    Somewhat difficult to focus                   Neutral       Good
# 3    Somewhat difficult to focus                      Good       Good
# 4             Very easy to focus                      Good       Good
# ..                           ...                       ...        ...
# 995  Somewhat difficult to focus                   Neutral       Good
# 996                      Neutral                   Neutral    Neutral
# 997  Somewhat difficult to focus                      Good       Good
# 998  Somewhat difficult to focus                   Neutral        Bad
# 999           Very easy to focus                      Fair       Good
#
#     Plan to Reduce Phone Usage                         Steps to Reduce Usage  \
# 0                          Yes                  Practice mindful phone usage
# 1                          Yes                        Set phone usage limits
# 2                           No                    Disable push notifications
# 3                          Yes                      Create a phone-free zone
# 4                           No                   Practice digital detox days
# ..                         ...                                           ...
# 995                         No                      Create a phone-free zone
# 996                        Yes                      Create a phone-free zone
# 997                         No                      Use a phone tracking app
# 998                         No  Set specific times for checking social media
# 999                         No                    Disable push notifications
#
#     expected_usage     sleep time
# 0             High      5-9 hours
# 1           Medium      5-9 hours
# 2             High  Above 9 hours
# 3             High  Below 5 hours
# 4              Low  Above 9 hours
# ..             ...            ...
# 995           High      5-9 hours
# 996            Low  Above 9 hours
# 997            Low  Above 9 hours
# 998         Medium  Above 9 hours
# 999           High      5-9 hours
#
# [1000 rows x 21 columns]

# %%
# data preprocessing
for index,row in df.iterrows():
    if row['Phone Reduction Attempt'] == 'No':
        df.at[index,'Reduction Success'] = None
        
df
# Out:
#                  NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0     Junette Griffin   22  Female    Student               Marketing
# 1        Donn Ricoald   32    Male    Teacher  Electrical Engineering
# 2        Brandon Gush   33    Male    Teacher                 Finance
# 3     Roger Littlekit   19    Male    Student               Marketing
# 4    Clarke Sterricks   27    Male    Teacher              Psychology
# ..                ...  ...     ...        ...                     ...
# 995  Eberhard Widmoor   20    Male    Student                 Finance
# 996   Beverley Mainds   20  Female    Student              Psychology
# 997      Jere Shaplin   30  Female    Teacher          Graphic Design
# 998      Hughie Rowet   36    Male    Teacher  Mechanical Engineering
# 999      Elle Rabbitt   33  Female    Teacher               Marketing
#
#     MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0               Yes          2-3 hours         Every hour        Twitter
# 1                No          1-2 hours   Every 15 minutes       Facebook
# 2               Yes  More than 5 hours  Every few minutes        Twitter
# 3               Yes          2-3 hours  Every few minutes      Instagram
# 4               Yes          1-2 hours  Every few minutes       Facebook
# ..              ...                ...                ...            ...
# 995              No          3-4 hours   Every 15 minutes        Twitter
# 996              No          2-3 hours   Every 15 minutes        Twitter
# 997              No          1-2 hours   Every 15 minutes      Instagram
# 998             Yes          3-4 hours   Every 15 minutes       Facebook
# 999              No          1-2 hours   Every 15 minutes      Instagram
#
#     Anxiety/Stress Away From Phone  ... SOCIAL ENGAGEMENT  \
# 0                              yes  ...            rarely
# 1                              yes  ...      occasionally
# 2                               No  ...        frequently
# 3                              yes  ...        frequently
# 4                               No  ...            rarely
# ..                             ...  ...               ...
# 995                            yes  ...        frequently
# 996                            yes  ...            rarely
# 997                             No  ...        frequently
# 998                             No  ...        frequently
# 999                            yes  ...        frequently
#
#     Phone Reduction Attempt    Reduction Success                Focus Ability  \
# 0                       Yes      Very successful                      Neutral
# 1                        No                 None                      Neutral
# 2                        No                 None  Somewhat difficult to focus
# 3                        No                 None  Somewhat difficult to focus
# 4                       Yes      Very successful           Very easy to focus
# ..                      ...                  ...                          ...
# 995                     Yes  Somewhat successful  Somewhat difficult to focus
# 996                      No                 None                      Neutral
# 997                     Yes  Somewhat successful  Somewhat difficult to focus
# 998                     Yes  Somewhat successful  Somewhat difficult to focus
# 999                     Yes  Somewhat successful           Very easy to focus
#
#     Phone Impact on Lifestyle WELL BEING Plan to Reduce Phone Usage  \
# 0                        Fair        Bad                        Yes
# 1                        Good        Bad                        Yes
# 2                     Neutral       Good                         No
# 3                        Good       Good                        Yes
# 4                        Good       Good                         No
# ..                        ...        ...                        ...
# 995                   Neutral       Good                         No
# 996                   Neutral    Neutral                        Yes
# 997                      Good       Good                         No
# 998                   Neutral        Bad                         No
# 999                      Fair       Good                         No
#
#                             Steps to Reduce Usage expected_usage  \
# 0                    Practice mindful phone usage           High
# 1                          Set phone usage limits         Medium
# 2                      Disable push notifications           High
# 3                        Create a phone-free zone           High
# 4                     Practice digital detox days            Low
# ..                                            ...            ...
# 995                      Create a phone-free zone           High
# 996                      Create a phone-free zone            Low
# 997                      Use a phone tracking app            Low
# 998  Set specific times for checking social media         Medium
# 999                    Disable push notifications           High
#
#         sleep time
# 0        5-9 hours
# 1        5-9 hours
# 2    Above 9 hours
# 3    Below 5 hours
# 4    Above 9 hours
# ..             ...
# 995      5-9 hours
# 996  Above 9 hours
# 997  Above 9 hours
# 998  Above 9 hours
# 999      5-9 hours
#
# [1000 rows x 21 columns]

# %%
# count no of different values in a particular column
df['Plan to Reduce Phone Usage'].value_counts()
# Out:
# Plan to Reduce Phone Usage
# Yes    500
# No     500
# Name: count, dtype: int64

# %%
# WHOLE DATASET
print(df)
# Out:
#                  NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0     Junette Griffin   22  Female    Student               Marketing
# 1        Donn Ricoald   32    Male    Teacher  Electrical Engineering
# 2        Brandon Gush   33    Male    Teacher                 Finance
# 3     Roger Littlekit   19    Male    Student               Marketing
# 4    Clarke Sterricks   27    Male    Teacher              Psychology
# ..                ...  ...     ...        ...                     ...
# 995  Eberhard Widmoor   20    Male    Student                 Finance
# 996   Beverley Mainds   20  Female    Student              Psychology
# 997      Jere Shaplin   30  Female    Teacher          Graphic Design
# 998      Hughie Rowet   36    Male    Teacher  Mechanical Engineering
# 999      Elle Rabbitt   33  Female    Teacher               Marketing
#
#     MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0               Yes          2-3 hours         Every hour        Twitter
# 1                No          1-2 hours   Every 15 minutes       Facebook
# 2               Yes  More than 5 hours  Every few minutes        Twitter
# 3               Yes          2-3 hours  Every few minutes      Instagram
# 4               Yes          1-2 hours  Every few minutes       Facebook
# ..              ...                ...                ...            ...
# 995              No          3-4 hours   Every 15 minutes        Twitter
# 996              No          2-3 hours   Every 15 minutes        Twitter
# 997              No          1-2 hours   Every 15 minutes      Instagram
# 998             Yes          3-4 hours   Every 15 minutes       Facebook
# 999              No          1-2 hours   Every 15 minutes      Instagram
#
#     Anxiety/Stress Away From Phone  ... SOCIAL ENGAGEMENT  \
# 0                              yes  ...            rarely
# 1                              yes  ...      occasionally
# 2                               No  ...        frequently
# 3                              yes  ...        frequently
# 4                               No  ...            rarely
# ..                             ...  ...               ...
# 995                            yes  ...        frequently
# 996                            yes  ...            rarely
# 997                             No  ...        frequently
# 998                             No  ...        frequently
# 999                            yes  ...        frequently
#
#     Phone Reduction Attempt    Reduction Success                Focus Ability  \
# 0                       Yes      Very successful                      Neutral
# 1                        No                 None                      Neutral
# 2                        No                 None  Somewhat difficult to focus
# 3                        No                 None  Somewhat difficult to focus
# 4                       Yes      Very successful           Very easy to focus
# ..                      ...                  ...                          ...
# 995                     Yes  Somewhat successful  Somewhat difficult to focus
# 996                      No                 None                      Neutral
# 997                     Yes  Somewhat successful  Somewhat difficult to focus
# 998                     Yes  Somewhat successful  Somewhat difficult to focus
# 999                     Yes  Somewhat successful           Very easy to focus
#
#     Phone Impact on Lifestyle WELL BEING Plan to Reduce Phone Usage  \
# 0                        Fair        Bad                        Yes
# 1                        Good        Bad                        Yes
# 2                     Neutral       Good                         No
# 3                        Good       Good                        Yes
# 4                        Good       Good                         No
# ..                        ...        ...                        ...
# 995                   Neutral       Good                         No
# 996                   Neutral    Neutral                        Yes
# 997                      Good       Good                         No
# 998                   Neutral        Bad                         No
# 999                      Fair       Good                         No
#
#                             Steps to Reduce Usage expected_usage  \
# 0                    Practice mindful phone usage           High
# 1                          Set phone usage limits         Medium
# 2                      Disable push notifications           High
# 3                        Create a phone-free zone           High
# 4                     Practice digital detox days            Low
# ..                                            ...            ...
# 995                      Create a phone-free zone           High
# 996                      Create a phone-free zone            Low
# 997                      Use a phone tracking app            Low
# 998  Set specific times for checking social media         Medium
# 999                    Disable push notifications           High
#
#         sleep time
# 0        5-9 hours
# 1        5-9 hours
# 2    Above 9 hours
# 3    Below 5 hours
# 4    Above 9 hours
# ..             ...
# 995      5-9 hours
# 996  Above 9 hours
# 997  Above 9 hours
# 998  Above 9 hours
# 999      5-9 hours
#
# [1000 rows x 21 columns]

# %%
# ALL THE ATTRIBUTES IN OUR DATASET
print(df.columns)
# Out:
# Index(['NAME', 'AGE', 'GENDER', 'OCCUPATION', 'FIELD OF STUDY',
#        'MEDICAL HISTORY', 'PHONE SCREEN TIME', 'FREQUENCY', 'SOCIAL HANDLES',
#        'Anxiety/Stress Away From Phone', 'Feeling Without Phone',
#        'SOCIAL ENGAGEMENT', 'Phone Reduction Attempt', 'Reduction Success',
#        'Focus Ability', 'Phone Impact on Lifestyle', 'WELL BEING',
#        'Plan to Reduce Phone Usage', 'Steps to Reduce Usage', 'expected_usage',
#        'sleep time'],
#       dtype='object')

# %% [markdown]
# # Now we have successfully completed the data preprocessing part of the project and our dataset is fully prepared for model building
#
# # The only thing we need to do right now is feature selection to select the main attributes we are going to use in our model which are as follows:
#
#
# ### 1. NAME
# ### 2. AGE
# ### 3. OCCUPATION
# ### 4. MEDICAL HISTORY
# ### 5. FIELD OF STUDY
# ### 6. PHONE SCREEN TIME
# ### 7. FREQUENCY
# ### 8. ANXIETY/STRESS AWAY FROM PHONE
# ### 9. SLEEP RANGE
# ### 10. EXPECTED USAGE
# ### 11. FOCUS ABILITY
# ### 12. WELL BEING

# %%
# data preprocessing
for index,row in df.iterrows():
    if row['Anxiety/Stress Away From Phone'] == 'No':
        df.at[index,'Anxiety/Stress Away From Phone'] = 0
        
    else:
        df.at[index,'Anxiety/Stress Away From Phone'] = 1
        
for index,row in df.iterrows():
    if row['Phone Reduction Attempt'] == 'No':
        df.at[index,'Phone Reduction Attempt'] = 0
        
    else:
        df.at[index,'Phone Reduction Attempt'] = 1

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# columns_of_interest = ['AGE', 'Anxiety/Stress Away From Phone', 'Phone Reduction Attempt']

# selected_df = df[columns_of_interest]

# correlation_matrix = selected_df.corr()
# plt.figure(figsize=(12, 10))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title('Correlation Heatmap')
# plt.show()
df.head()
# Out:
#                NAME  AGE  GENDER OCCUPATION          FIELD OF STUDY  \
# 0   Junette Griffin   22  Female    Student               Marketing
# 1      Donn Ricoald   32    Male    Teacher  Electrical Engineering
# 2      Brandon Gush   33    Male    Teacher                 Finance
# 3   Roger Littlekit   19    Male    Student               Marketing
# 4  Clarke Sterricks   27    Male    Teacher              Psychology
#
#   MEDICAL HISTORY  PHONE SCREEN TIME          FREQUENCY SOCIAL HANDLES  \
# 0             Yes          2-3 hours         Every hour        Twitter
# 1              No          1-2 hours   Every 15 minutes       Facebook
# 2             Yes  More than 5 hours  Every few minutes        Twitter
# 3             Yes          2-3 hours  Every few minutes      Instagram
# 4             Yes          1-2 hours  Every few minutes       Facebook
#
#   Anxiety/Stress Away From Phone  ... SOCIAL ENGAGEMENT  \
# 0                              1  ...            rarely
# 1                              1  ...      occasionally
# 2                              0  ...        frequently
# 3                              1  ...        frequently
# 4                              0  ...            rarely
#
#   Phone Reduction Attempt Reduction Success                Focus Ability  \
# 0                       1   Very successful                      Neutral
# 1                       0              None                      Neutral
# 2                       0              None  Somewhat difficult to focus
# 3                       0              None  Somewhat difficult to focus
# 4                       1   Very successful           Very easy to focus
#
#   Phone Impact on Lifestyle WELL BEING Plan to Reduce Phone Usage  \
# 0                      Fair        Bad                        Yes
# 1                      Good        Bad                        Yes
# 2                   Neutral       Good                         No
# 3                      Good       Good                        Yes
# 4                      Good       Good                         No
#
#           Steps to Reduce Usage expected_usage     sleep time
# 0  Practice mindful phone usage           High      5-9 hours
# 1        Set phone usage limits         Medium      5-9 hours
# 2    Disable push notifications           High  Above 9 hours
# 3      Create a phone-free zone           High  Below 5 hours
# 4   Practice digital detox days            Low  Above 9 hours
#
# [5 rows x 21 columns]

# %%
df.to_csv('final.csv',index=False)

# %% [markdown]
# # PHQ-9 CLASSIFICATION

# %%
data = pd.read_csv('finalphq-9.csv')
data
# Out:
#      phq1  phq2  phq3  phq4  phq5  phq6  phq7  phq8  phq9
# 0       2     4     2     1     2     2     1     3     2
# 1       2     4     1     4     1     1     2     4     1
# 2       1     2     4     1     3     2     2     3     1
# 3       2     2     3     3     3     2     2     2     4
# 4       2     4     4     2     2     1     4     4     4
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 995     2     2     4     4     3     4     1     1     3
# 996     1     2     3     3     3     3     1     4     1
# 997     4     2     3     4     4     2     3     4     2
# 998     3     3     4     2     1     3     4     1     3
# 999     1     1     1     3     2     4     1     1     4
#
# [1000 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report


data['SUM'] = data.sum(axis=1)
print(data['SUM'].max())
def categorize_sum(score):
    if 9 <= score <= 14:
        return 'Minimal depression'
    elif 15 <= score <= 19:
        return 'Mild depression'
    elif 20 <= score <= 24:
        return 'Moderate depression'
    elif 25 <= score <= 29:
        return 'Moderately severe depression'
    elif 30 <= score <= 36:
        return 'Severe depression'
    else:
        return 'No depression'

data['Depression_Severity'] = data['SUM'].apply(categorize_sum)
X = data.drop(['SUM', 'Depression_Severity'], axis=1)
y = data['Depression_Severity'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

predictions = rf_classifier.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
classification_rep = classification_report(y_test, predictions)

print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_rep)
# Out:
# 33
# Accuracy: 0.78
# Classification Report:
#                               precision    recall  f1-score   support
#
#              Mild depression       0.96      0.47      0.63        49
#          Moderate depression       0.75      0.98      0.85       176
# Moderately severe depression       0.86      0.54      0.66        71
#            Severe depression       0.00      0.00      0.00         4
#
#                     accuracy                           0.78       300
#                    macro avg       0.64      0.50      0.53       300
#                 weighted avg       0.80      0.78      0.76       300
# C:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
